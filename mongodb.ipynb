# %%
import pymongo 
from pymongo import MongoClient

# %%
connection_string = "(mongo connection string here)"

# %%
client = MongoClient(connection_string)

# %%
db = client["liveclass"]

# %%
collection = db["mongoclass"]

# %%
data = {
    "name": "Keshavi Verma",
    "age": 22,
    "email": "2k22.cse.2213443@gmail.com"
}

# %%
collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('691af1ee8f2ec67673cc4464'), acknowledged=True)

# %%
cursor = collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('68e600eccd39fafb4336be8e'), 'name': 'Keshavi Verma', 'age': 22, 'email': '2k22.cse.2213443@gmail.com'}
# {'_id': ObjectId('691a9f8f59d2542bf58fd45c'), 'name': 'Keshavi Verma', 'age': 22, 'email': '2k22.cse.2213443@gmail.com'}
# {'_id': ObjectId('691af1ee8f2ec67673cc4464'), 'name': 'Keshavi Verma', 'age': 22, 'email': '2k22.cse.2213443@gmail.com'}
