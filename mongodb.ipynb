# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in d:\aps_fault_detection\venv\lib\site-packages (4.15.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in d:\aps_fault_detection\venv\lib\site-packages (from pymongo) (2.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo 
from pymongo import MongoClient

# %%
connection_string = "mongodb+srv://KeshaviVerma:Kishu#2502@cluster.6uynrcd.mongodb.net/?retryWrites=true&w=majority&appName=Cluster"

# %%
client = MongoClient(connection_string)

# %%
db = client["liveclass"]

# %%
collection = db["mongoclass"]

# %%
data = {
    "name": "Keshavi Verma",
    "age": 22,
    "email": "2k22.cse.2213443@gmail.com"
}

# %%
collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('68e600eccd39fafb4336be8e'), acknowledged=True)

# %%
cursor = collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('68e600eccd39fafb4336be8e'), 'name': 'Keshavi Verma', 'age': 22, 'email': '2k22.cse.2213443@gmail.com'}
